# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#df = pd.read_csv('hp-02.csv')
#df

x = np.arange(0, 5, 0.1);
y = np.exp(x)
y1 = x *20
plt.plot(x, y)
plt.plot(x, y1)
for ix in range(0,1):
    print(ix+1,'Sara')
# Out:
# 1 Sara

# %% [markdown]
# $$c = \sqrt{a^2 + b^2}$$
